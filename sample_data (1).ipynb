# %% [markdown]
# ### Imports

# %%
# !pip install pandas matplotlib scikit-learn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/hackton/data_sst_reto_coppel.csv', index_col='Unnamed: 0')

# %%
print(df.shape)
df.head()
# Out:
# (18510772, 9)
#              Fecha Segmento  hora_llegada  hora_llamado  hora_salida    caja  \
# 821243  2023-01-01   retail      0.503465      0.503477     0.503581  caja_a
# 821244  2023-01-01   retail      0.503581      0.503616     0.511174  caja_a
# 821245  2023-01-01   retail      0.503789      0.503801     0.505120  caja_b
# 821246  2023-01-01   retail      0.503847      0.505132     0.509333  caja_b
# 821247  2023-01-01   retail      0.503894      0.508072     0.509981  caja_c
#
#           tienda    status            estado
# 821243  Tienda_A  Atendido  Ciudad de México
# 821244  Tienda_A  Atendido  Ciudad de México
# 821245  Tienda_A  Atendido  Ciudad de México
# 821246  Tienda_A  Atendido  Ciudad de México
# 821247  Tienda_A  Atendido  Ciudad de México

# %% [markdown]
# ### Sample

# %%
import pandas as pd

# Definir tamaño de la muestra
sample_frac = 0.1

# Aplicar muestreo estratificado manualmente
df_sample = df.groupby(['estado', 'tienda'], group_keys=False).apply(lambda x: x.sample(frac=sample_frac, random_state=42))

# Resetear índices
df_sample = df_sample.reset_index(drop=True)
# Out:
# <ipython-input-7-091d92e8cd59>:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_sample = df.groupby(['estado', 'tienda'], group_keys=False).apply(lambda x: x.sample(frac=sample_frac, random_state=42))

# %%
df_sample.head()
# Out:
#         Fecha Segmento  hora_llegada  hora_llamado  hora_salida          caja  \
# 0  2023-11-10   retail      0.796926      0.800271     0.805201        caja_c
# 1  2023-02-15   retail      0.518188      0.521220     0.531093        caja_b
# 2  2023-11-22    banco      0.741174      0.742771     0.746590  ventanilla_c
# 3  2023-06-05    banco      0.516845      0.517470     0.518720  ventanilla_a
# 4  2023-03-04    banco      0.783315      0.785606     0.786463  ventanilla_c
#
#       tienda    status           estado
# 0  Tienda_AH  Atendido  Baja California
# 1  Tienda_AH  Atendido  Baja California
# 2  Tienda_AH  Atendido  Baja California
# 3  Tienda_AH  Atendido  Baja California
# 4  Tienda_AH  Atendido  Baja California

# %%
print(df_sample.shape)
print(df_sample.info())
# Out:
# (1851075, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1851075 entries, 0 to 1851074
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Fecha         object
#  1   Segmento      object
#  2   hora_llegada  float64
#  3   hora_llamado  float64
#  4   hora_salida   float64
#  5   caja          object
#  6   tienda        object
#  7   status        object
#  8   estado        object
# dtypes: float64(3), object(6)
# memory usage: 127.1+ MB
# None
